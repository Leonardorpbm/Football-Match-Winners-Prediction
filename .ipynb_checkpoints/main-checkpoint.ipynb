# %%
import pandas as pd

# %%
# Reading the CSV file
matches = pd.read_csv('matches.csv', index_col=0)

# %% [markdown]
# ### Data of Premier League Matches

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2023-08-12  12:30  Premier League  Matchweek 1  Sat  Home      W  2.0  1.0
# 2  2023-08-21  20:00  Premier League  Matchweek 2  Mon  Away      W  1.0  0.0
# 3  2023-08-26  15:00  Premier League  Matchweek 3  Sat  Home      D  2.0  2.0
# 4  2023-09-03  16:30  Premier League  Matchweek 4  Sun  Home      W  3.0  1.0
# 5  2023-09-17  16:30  Premier League  Matchweek 5  Sun  Away      W  1.0  0.0
#
#           opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 1  Nott'ham Forest  ...  Match Report    NaN  15.0  7.0  19.1  0.0  0     0
# 2   Crystal Palace  ...  Match Report    NaN  13.0  2.0  16.4  0.0  1     1
# 3           Fulham  ...  Match Report    NaN  18.0  9.0  13.8  0.0  1     1
# 4   Manchester Utd  ...  Match Report    NaN  17.0  5.0  15.0  0.0  0     0
# 5          Everton  ...  Match Report    NaN  13.0  4.0  17.4  0.0  0     0
#
#    season     team
# 1    2024  Arsenal
# 2    2024  Arsenal
# 3    2024  Arsenal
# 4    2024  Arsenal
# 5    2024  Arsenal
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1780, 27)

# %% [markdown]
# ### Investigating Missing Data

# %%
# 38 games, 20 teams, 2 seasons
38 * 20 * 2
# Out:
# 1520

# %%
# Displaying the count of occurrences for each unique value in the "team" column of the matches DataFrame.
matches["team"].value_counts()
# Out:
# team
# Arsenal                     89
# West Ham United             89
# Everton                     89
# Manchester City             89
# Wolverhampton Wanderers     89
# Brentford                   89
# Chelsea                     89
# Crystal Palace              89
# Brighton and Hove Albion    89
# Manchester United           89
# Tottenham Hotspur           89
# Aston Villa                 89
# Newcastle United            89
# Liverpool                   89
# Southampton                 76
# Leicester City              76
# Leeds United                76
# Fulham                      51
# Nottingham Forest           51
# Bournemouth                 51
# Burnley                     51
# Watford                     38
# Norwich City                38
# Sheffield United            13
# Luton Town                  13
# Name: count, dtype: int64

# %%
# Filtering the matches DataFrame to display rows where the "team" column is equal to "Fulham".
matches[matches["team"] == "Fulham"]
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-12  15:00  Premier League   Matchweek 1  Sat  Away      W  1.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      L  0.0
# 2   2023-08-26  15:00  Premier League   Matchweek 3  Sat  Away      D  2.0
# 4   2023-09-02  15:00  Premier League   Matchweek 4  Sat  Away      L  1.0
# 5   2023-09-16  15:00  Premier League   Matchweek 5  Sat  Home      W  1.0
# 6   2023-09-23  15:00  Premier League   Matchweek 6  Sat  Away      D  0.0
# 8   2023-10-02  20:00  Premier League   Matchweek 7  Mon  Home      L  0.0
# 9   2023-10-07  15:00  Premier League   Matchweek 8  Sat  Home      W  3.0
# 10  2023-10-23  20:00  Premier League   Matchweek 9  Mon  Away      L  0.0
# 11  2023-10-29  14:00  Premier League  Matchweek 10  Sun  Away      D  1.0
# 13  2023-11-04  12:30  Premier League  Matchweek 11  Sat  Home      L  0.0
# 14  2023-11-12  14:00  Premier League  Matchweek 12  Sun  Away      L  1.0
# 15  2023-11-27  20:00  Premier League  Matchweek 13  Mon  Home      W  3.0
# 0   2022-08-06  12:30  Premier League   Matchweek 1  Sat  Home      D  2.0
# 1   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Away      D  0.0
# 2   2022-08-20  15:00  Premier League   Matchweek 3  Sat  Home      W  3.0
# 4   2022-08-27  17:30  Premier League   Matchweek 4  Sat  Away      L  1.0
# 5   2022-08-30  19:30  Premier League   Matchweek 5  Tue  Home      W  2.0
# 6   2022-09-03  15:00  Premier League   Matchweek 6  Sat  Away      L  1.0
# 7   2022-09-16  20:00  Premier League   Matchweek 8  Fri  Away      W  3.0
# 8   2022-10-01  15:00  Premier League   Matchweek 9  Sat  Home      L  1.0
# 9   2022-10-09  14:00  Premier League  Matchweek 10  Sun  Away      L  1.0
# 10  2022-10-15  15:00  Premier League  Matchweek 11  Sat  Home      D  2.0
# 11  2022-10-20  19:30  Premier League  Matchweek 12  Thu  Home      W  3.0
# 12  2022-10-23  14:00  Premier League  Matchweek 13  Sun  Away      W  3.0
# 13  2022-10-29  17:30  Premier League  Matchweek 14  Sat  Home      D  0.0
# 14  2022-11-05  15:00  Premier League  Matchweek 15  Sat  Away      L  1.0
# 15  2022-11-13  16:30  Premier League  Matchweek 16  Sun  Home      L  1.0
# 16  2022-12-26  15:00  Premier League  Matchweek 17  Mon  Away      W  3.0
# 17  2022-12-31  15:00  Premier League  Matchweek 18  Sat  Home      W  2.0
# 18  2023-01-03  19:45  Premier League  Matchweek 19  Tue  Away      W  1.0
# 20  2023-01-12  20:00  Premier League   Matchweek 7  Thu  Home      W  2.0
# 21  2023-01-15  14:00  Premier League  Matchweek 20  Sun  Away      L  0.0
# 22  2023-01-23  20:00  Premier League  Matchweek 21  Mon  Home      L  0.0
# 24  2023-02-03  20:00  Premier League  Matchweek 22  Fri  Away      D  0.0
# 26  2023-02-11  15:00  Premier League  Matchweek 23  Sat  Home      W  2.0
# 27  2023-02-18  15:00  Premier League  Matchweek 24  Sat  Away      W  1.0
# 28  2023-02-24  20:00  Premier League  Matchweek 25  Fri  Home      D  1.0
# 30  2023-03-06  20:00  Premier League  Matchweek 26  Mon  Away      L  2.0
# 31  2023-03-12  14:00  Premier League  Matchweek 27  Sun  Home      L  0.0
# 33  2023-04-01  15:00  Premier League  Matchweek 29  Sat  Away      L  1.0
# 34  2023-04-08  15:00  Premier League  Matchweek 30  Sat  Home      L  0.0
# 35  2023-04-15  15:00  Premier League  Matchweek 31  Sat  Away      W  3.0
# 36  2023-04-22  12:30  Premier League  Matchweek 32  Sat  Home      W  2.0
# 37  2023-04-25  19:45  Premier League  Matchweek 33  Tue  Away      L  0.0
# 38  2023-04-30  14:00  Premier League  Matchweek 34  Sun  Home      L  1.0
# 39  2023-05-03  20:00  Premier League  Matchweek 28  Wed  Away      L  0.0
# 40  2023-05-08  15:00  Premier League  Matchweek 35  Mon  Home      W  5.0
# 41  2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      W  2.0
# 42  2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D  2.0
# 43  2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L  1.0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk pk  \
# 0   0.0          Everton  ...  Match Report    NaN   9.0   2.0  13.2  0.0  0
# 1   3.0        Brentford  ...  Match Report    NaN  10.0   2.0  22.3  1.0  0
# 2   2.0          Arsenal  ...  Match Report    NaN   8.0   3.0  17.8  0.0  0
# 4   5.0  Manchester City  ...  Match Report    NaN   6.0   4.0  11.4  0.0  0
# 5   0.0       Luton Town  ...  Match Report    NaN  13.0   2.0  19.5  2.0  0
# 6   0.0   Crystal Palace  ...  Match Report    NaN  10.0   5.0  18.7  1.0  0
# 8   2.0          Chelsea  ...  Match Report    NaN  10.0   3.0  13.2  0.0  0
# 9   1.0    Sheffield Utd  ...  Match Report    NaN  20.0   6.0  20.2  0.0  0
# 10  2.0        Tottenham  ...  Match Report    NaN  10.0   3.0  17.6  0.0  0
# 11  1.0         Brighton  ...  Match Report    NaN  10.0   5.0  19.3  0.0  0
# 13  1.0   Manchester Utd  ...  Match Report    NaN  18.0   2.0  18.6  1.0  0
# 14  3.0      Aston Villa  ...  Match Report    NaN   9.0   5.0  19.5  0.0  0
# 15  2.0           Wolves  ...  Match Report    NaN  10.0   4.0  22.9  0.0  2
# 0   2.0        Liverpool  ...  Match Report    NaN   8.0   2.0  18.4  0.0  1
# 1   0.0           Wolves  ...  Match Report    NaN   8.0   2.0  15.7  0.0  0
# 2   2.0        Brentford  ...  Match Report    NaN  18.0   9.0  15.5  1.0  0
# 4   2.0          Arsenal  ...  Match Report    NaN  11.0   3.0  13.7  0.0  0
# 5   1.0         Brighton  ...  Match Report    NaN  10.0   3.0  15.3  1.0  0
# 6   2.0        Tottenham  ...  Match Report    NaN   9.0   3.0  17.1  0.0  0
# 7   2.0  Nott'ham Forest  ...  Match Report    NaN  15.0   7.0  17.3  2.0  0
# 8   4.0    Newcastle Utd  ...  Match Report    NaN   3.0   1.0  16.2  0.0  0
# 9   3.0         West Ham  ...  Match Report    NaN   8.0   2.0  16.6  1.0  0
# 10  2.0      Bournemouth  ...  Match Report    NaN  18.0   3.0  18.9  0.0  1
# 11  0.0      Aston Villa  ...  Match Report    NaN  17.0   6.0  16.7  1.0  1
# 12  2.0     Leeds United  ...  Match Report    NaN  11.0   4.0  11.9  0.0  0
# 13  0.0          Everton  ...  Match Report    NaN  24.0   6.0  16.4  0.0  0
# 14  2.0  Manchester City  ...  Match Report    NaN   3.0   1.0  26.2  0.0  1
# 15  2.0   Manchester Utd  ...  Match Report    NaN  14.0   7.0  14.0  0.0  0
# 16  0.0   Crystal Palace  ...  Match Report    NaN  23.0  10.0  13.4  1.0  0
# 17  1.0      Southampton  ...  Match Report    NaN   7.0   1.0  18.8  0.0  0
# 18  0.0   Leicester City  ...  Match Report    NaN  11.0   2.0  19.4  0.0  0
# 20  1.0          Chelsea  ...  Match Report    NaN   8.0   3.0  15.3  0.0  0
# 21  1.0    Newcastle Utd  ...  Match Report    NaN   4.0   0.0  18.9  0.0  0
# 22  1.0        Tottenham  ...  Match Report    NaN  10.0   5.0  17.3  1.0  0
# 24  0.0          Chelsea  ...  Match Report    NaN  10.0   4.0  23.0  0.0  0
# 26  0.0  Nott'ham Forest  ...  Match Report    NaN  16.0   3.0  15.0  1.0  0
# 27  0.0         Brighton  ...  Match Report    NaN   5.0   2.0  16.0  0.0  0
# 28  1.0           Wolves  ...  Match Report    NaN  10.0   5.0  24.2  1.0  0
# 30  3.0        Brentford  ...  Match Report    NaN   9.0   5.0  17.4  1.0  0
# 31  3.0          Arsenal  ...  Match Report    NaN  12.0   2.0  17.4  0.0  0
# 33  2.0      Bournemouth  ...  Match Report    NaN  10.0   2.0  16.5  0.0  0
# 34  1.0         West Ham  ...  Match Report    NaN  16.0   3.0  20.5  0.0  0
# 35  1.0          Everton  ...  Match Report    NaN  21.0   7.0  17.9  0.0  0
# 36  1.0     Leeds United  ...  Match Report    NaN  12.0   5.0  24.4  3.0  0
# 37  1.0      Aston Villa  ...  Match Report    NaN   1.0   0.0  14.7  0.0  0
# 38  2.0  Manchester City  ...  Match Report    NaN   4.0   1.0  22.4  0.0  0
# 39  1.0        Liverpool  ...  Match Report    NaN   9.0   3.0  16.8  0.0  0
# 40  3.0   Leicester City  ...  Match Report    NaN  17.0   7.0  17.5  1.0  0
# 41  0.0      Southampton  ...  Match Report    NaN   9.0   3.0  17.5  0.0  0
# 42  2.0   Crystal Palace  ...  Match Report    NaN  10.0   3.0  19.0  1.0  1
# 43  2.0   Manchester Utd  ...  Match Report    NaN   9.0   2.0  17.6  1.0  0
#
#    pkatt  season    team
# 0      0    2024  Fulham
# 1      0    2024  Fulham
# 2      0    2024  Fulham
# 4      0    2024  Fulham
# 5      0    2024  Fulham
# 6      0    2024  Fulham
# 8      0    2024  Fulham
# 9      0    2024  Fulham
# 10     0    2024  Fulham
# 11     0    2024  Fulham
# 13     0    2024  Fulham
# 14     0    2024  Fulham
# 15     2    2024  Fulham
# 0      1    2023  Fulham
# 1      1    2023  Fulham
# 2      0    2023  Fulham
# 4      0    2023  Fulham
# 5      0    2023  Fulham
# 6      0    2023  Fulham
# 7      0    2023  Fulham
# 8      0    2023  Fulham
# 9      0    2023  Fulham
# 10     1    2023  Fulham
# 11     1    2023  Fulham
# 12     0    2023  Fulham
# 13     0    2023  Fulham
# 14     1    2023  Fulham
# 15     0    2023  Fulham
# 16     0    2023  Fulham
# 17     1    2023  Fulham
# 18     0    2023  Fulham
# 20     0    2023  Fulham
# 21     1    2023  Fulham
# 22     0    2023  Fulham
# 24     0    2023  Fulham
# 26     0    2023  Fulham
# 27     0    2023  Fulham
# 28     0    2023  Fulham
# 30     0    2023  Fulham
# 31     0    2023  Fulham
# 33     0    2023  Fulham
# 34     0    2023  Fulham
# 35     0    2023  Fulham
# 36     0    2023  Fulham
# 37     0    2023  Fulham
# 38     0    2023  Fulham
# 39     0    2023  Fulham
# 40     0    2023  Fulham
# 41     0    2023  Fulham
# 42     1    2023  Fulham
# 43     1    2023  Fulham
#
# [51 rows x 27 columns]

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     60
# Matchweek 8     60
# Matchweek 2     60
# Matchweek 12    60
# Matchweek 11    60
# Matchweek 10    60
# Matchweek 9     60
# Matchweek 13    60
# Matchweek 7     60
# Matchweek 5     60
# Matchweek 4     60
# Matchweek 6     60
# Matchweek 3     60
# Matchweek 34    40
# Matchweek 29    40
# Matchweek 30    40
# Matchweek 31    40
# Matchweek 33    40
# Matchweek 35    40
# Matchweek 28    40
# Matchweek 36    40
# Matchweek 37    40
# Matchweek 32    40
# Matchweek 26    40
# Matchweek 27    40
# Matchweek 20    40
# Matchweek 25    40
# Matchweek 24    40
# Matchweek 23    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 19    40
# Matchweek 18    40
# Matchweek 17    40
# Matchweek 16    40
# Matchweek 15    40
# Matchweek 14    40
# Matchweek 38    40
# Name: count, dtype: int64

# %% [markdown]
# ### Cleaning Data

# %%
# Convert Date to datetime
matches["date"] = pd.to_datetime(matches["date"])

# %% [markdown]
# ### Creating Predictions

# %%
# Introducing a new column, "venue_code," in the matches DataFrame, encoding numerical values for each unique entry in the "venue" column.
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
# Remove the : and minutes from hour column
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["referee_code"] = matches["referee"].astype("category").cat.codes

# %%
matches["captain_code"] = matches["captain"].astype("category").cat.codes

# %%
# Creating a new column, "target," in the matches DataFrame, assigning binary values (1 for "W" (Win) and 0 for other results) based on the "result" column.
matches["target"] = (matches["result"] == "W").astype("int")

# %% [markdown]
# ### Machine Learning Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
test = matches[matches["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code", "referee_code", "captain_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.627906976744186

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           342  77
# 1           179  90

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.5389221556886228

# %% [markdown]
# ### Improving Precision

# %%
grouped_matches =  matches.groupby("team")

# %%
group = grouped_matches.get_group("Arsenal")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 12 2023-10-21  17:30  Premier League   Matchweek 9  Sat  Away      D  2.0
# 14 2023-10-28  15:00  Premier League  Matchweek 10  Sat  Home      W  5.0
# 16 2023-11-04  17:30  Premier League  Matchweek 11  Sat  Away      L  0.0
# 18 2023-11-11  15:00  Premier League  Matchweek 12  Sat  Home      W  3.0
# 19 2023-11-25  17:30  Premier League  Matchweek 13  Sat  Away      W  1.0
#
#      ga        opponent  ...  captain_code  target  gf_rolling  ga_rolling  \
# 4   0.0    Norwich City  ...            88       1    0.000000    3.000000
# 5   0.0         Burnley  ...            88       1    0.333333    2.333333
# 7   1.0       Tottenham  ...            88       1    0.666667    1.666667
# 8   0.0        Brighton  ...            88       0    1.666667    0.333333
# 9   2.0  Crystal Palace  ...            88       0    1.333333    0.333333
# ..  ...             ...  ...           ...     ...         ...         ...
# 12  2.0         Chelsea  ...            75       0    2.333333    0.666667
# 14  0.0   Sheffield Utd  ...            15       1    2.333333    0.666667
# 16  1.0   Newcastle Utd  ...            55       0    2.666667    0.666667
# 18  1.0         Burnley  ...            55       1    2.333333    1.000000
# 19  0.0       Brentford  ...            75       1    2.666667    0.666667
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4    9.666667    2.333333    14.833333   0.333333    0.000000       0.000000
# 5   12.333333    3.000000    14.133333   0.333333    0.000000       0.000000
# 7   14.666667    3.000000    14.800000   0.666667    0.000000       0.000000
# 8   18.333333    5.333333    18.433333   0.666667    0.000000       0.000000
# 9   11.000000    4.000000    19.833333   0.666667    0.000000       0.000000
# ..        ...         ...          ...        ...         ...            ...
# 12  12.333333    4.000000    17.200000   0.000000    1.000000       1.000000
# 14  12.666667    3.666667    16.333333   0.000000    0.666667       0.666667
# 16  12.333333    3.666667    16.833333   0.000000    0.333333       0.333333
# 18  13.000000    3.333333    17.333333   0.000000    0.333333       0.333333
# 19  14.000000    4.333333    17.166667   0.000000    0.333333       0.333333
#
# [86 rows x 42 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2021-09-11  15:00  Premier League   Matchweek 4
#                         5  2021-09-18  15:00  Premier League   Matchweek 5
#                         7  2021-09-26  16:30  Premier League   Matchweek 6
#                         8  2021-10-02  17:30  Premier League   Matchweek 7
#                         9  2021-10-18  20:00  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 10 2023-10-21  15:00  Premier League   Matchweek 9
#                         11 2023-10-28  17:30  Premier League  Matchweek 10
#                         12 2023-11-04  15:00  Premier League  Matchweek 11
#                         13 2023-11-11  12:30  Premier League  Matchweek 12
#                         14 2023-11-27  20:00  Premier League  Matchweek 13
#
#                             day venue result   gf   ga        opponent  ...  \
# team                                                                    ...
# Arsenal                 4   Sat  Home      W  1.0  0.0    Norwich City  ...
#                         5   Sat  Away      W  1.0  0.0         Burnley  ...
#                         7   Sun  Home      W  3.0  1.0       Tottenham  ...
#                         8   Sat  Away      D  0.0  0.0        Brighton  ...
#                         9   Mon  Home      D  2.0  2.0  Crystal Palace  ...
# ...                         ...   ...    ...  ...  ...             ...  ...
# Wolverhampton Wanderers 10  Sat  Away      W  2.0  1.0     Bournemouth  ...
#                         11  Sat  Home      D  2.0  2.0   Newcastle Utd  ...
#                         12  Sat  Away      L  1.0  2.0   Sheffield Utd  ...
#                         13  Sat  Home      W  2.0  1.0       Tottenham  ...
#                         14  Mon  Away      L  2.0  3.0          Fulham  ...
#
#                             captain_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 4             88       1    0.000000    3.000000
#                         5             88       1    0.333333    2.333333
#                         7             88       1    0.666667    1.666667
#                         8             88       0    1.666667    0.333333
#                         9             88       0    1.333333    0.333333
# ...                                  ...     ...         ...         ...
# Wolverhampton Wanderers 10            77       1    1.333333    1.000000
#                         11            77       0    1.666667    1.000000
#                         12            77       0    1.666667    1.333333
#                         13            77       1    1.666667    1.666667
#                         14            77       0    1.666667    1.666667
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 4    9.666667    2.333333    14.833333   0.333333
#                         5   12.333333    3.000000    14.133333   0.333333
#                         7   14.666667    3.000000    14.800000   0.666667
#                         8   18.333333    5.333333    18.433333   0.666667
#                         9   11.000000    4.000000    19.833333   0.666667
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 10   4.666667    2.333333    11.466667   0.000000
#                         11  10.666667    3.666667    14.533333   0.000000
#                         12  13.333333    5.333333    16.466667   0.333333
#                         13  14.000000    5.333333    16.966667   0.666667
#                         14  12.666667    4.333333    17.733333   0.666667
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 4          0.0            0.0
#                         5          0.0            0.0
#                         7          0.0            0.0
#                         8          0.0            0.0
#                         9          0.0            0.0
# ...                                ...            ...
# Wolverhampton Wanderers 10         0.0            0.0
#                         11         0.0            0.0
#                         12         0.0            0.0
#                         13         0.0            0.0
#                         14         0.0            0.0
#
# [1705 rows x 42 columns]

# %%
# Removing name teams
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 10 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Away      W  2.0
# 11 2023-10-28  17:30  Premier League  Matchweek 10  Sat  Home      D  2.0
# 12 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Away      L  1.0
# 13 2023-11-11  12:30  Premier League  Matchweek 12  Sat  Home      W  2.0
# 14 2023-11-27  20:00  Premier League  Matchweek 13  Mon  Away      L  2.0
#
#      ga        opponent  ...  captain_code  target  gf_rolling  ga_rolling  \
# 4   0.0    Norwich City  ...            88       1    0.000000    3.000000
# 5   0.0         Burnley  ...            88       1    0.333333    2.333333
# 7   1.0       Tottenham  ...            88       1    0.666667    1.666667
# 8   0.0        Brighton  ...            88       0    1.666667    0.333333
# 9   2.0  Crystal Palace  ...            88       0    1.333333    0.333333
# ..  ...             ...  ...           ...     ...         ...         ...
# 10  1.0     Bournemouth  ...            77       1    1.333333    1.000000
# 11  2.0   Newcastle Utd  ...            77       0    1.666667    1.000000
# 12  2.0   Sheffield Utd  ...            77       0    1.666667    1.333333
# 13  1.0       Tottenham  ...            77       1    1.666667    1.666667
# 14  3.0          Fulham  ...            77       0    1.666667    1.666667
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4    9.666667    2.333333    14.833333   0.333333         0.0            0.0
# 5   12.333333    3.000000    14.133333   0.333333         0.0            0.0
# 7   14.666667    3.000000    14.800000   0.666667         0.0            0.0
# 8   18.333333    5.333333    18.433333   0.666667         0.0            0.0
# 9   11.000000    4.000000    19.833333   0.666667         0.0            0.0
# ..        ...         ...          ...        ...         ...            ...
# 10   4.666667    2.333333    11.466667   0.000000         0.0            0.0
# 11  10.666667    3.666667    14.533333   0.000000         0.0            0.0
# 12  13.333333    5.333333    16.466667   0.333333         0.0            0.0
# 13  14.000000    5.333333    16.966667   0.666667         0.0            0.0
# 14  12.666667    4.333333    17.733333   0.666667         0.0            0.0
#
# [1705 rows x 42 columns]

# %%
# Reassigning index
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 1    2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 2    2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 3    2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 4    2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1700 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Away      W  2.0
# 1701 2023-10-28  17:30  Premier League  Matchweek 10  Sat  Home      D  2.0
# 1702 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Away      L  1.0
# 1703 2023-11-11  12:30  Premier League  Matchweek 12  Sat  Home      W  2.0
# 1704 2023-11-27  20:00  Premier League  Matchweek 13  Mon  Away      L  2.0
#
#        ga        opponent  ...  captain_code  target  gf_rolling  ga_rolling  \
# 0     0.0    Norwich City  ...            88       1    0.000000    3.000000
# 1     0.0         Burnley  ...            88       1    0.333333    2.333333
# 2     1.0       Tottenham  ...            88       1    0.666667    1.666667
# 3     0.0        Brighton  ...            88       0    1.666667    0.333333
# 4     2.0  Crystal Palace  ...            88       0    1.333333    0.333333
# ...   ...             ...  ...           ...     ...         ...         ...
# 1700  1.0     Bournemouth  ...            77       1    1.333333    1.000000
# 1701  2.0   Newcastle Utd  ...            77       0    1.666667    1.000000
# 1702  2.0   Sheffield Utd  ...            77       0    1.666667    1.333333
# 1703  1.0       Tottenham  ...            77       1    1.666667    1.666667
# 1704  3.0          Fulham  ...            77       0    1.666667    1.666667
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      9.666667    2.333333    14.833333   0.333333         0.0            0.0
# 1     12.333333    3.000000    14.133333   0.333333         0.0            0.0
# 2     14.666667    3.000000    14.800000   0.666667         0.0            0.0
# 3     18.333333    5.333333    18.433333   0.666667         0.0            0.0
# 4     11.000000    4.000000    19.833333   0.666667         0.0            0.0
# ...         ...         ...          ...        ...         ...            ...
# 1700   4.666667    2.333333    11.466667   0.000000         0.0            0.0
# 1701  10.666667    3.666667    14.533333   0.000000         0.0            0.0
# 1702  13.333333    5.333333    16.466667   0.333333         0.0            0.0
# 1703  14.000000    5.333333    16.966667   0.666667         0.0            0.0
# 1704  12.666667    4.333333    17.733333   0.666667         0.0            0.0
#
# [1705 rows x 42 columns]

# %% [markdown]
# ### Retraining the model

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], prediction=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5773809523809523

# %%
combined
# Out:
#       actual  prediction
# 51         0           1
# 52         1           1
# 53         1           1
# 54         0           0
# 55         0           1
# ...      ...         ...
# 1700       1           0
# 1701       0           0
# 1702       0           0
# 1703       1           1
# 1704       0           0
#
# [682 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  prediction       date                     team        opponent  \
# 51         0           1 2023-01-03                  Arsenal   Newcastle Utd
# 52         1           1 2023-01-15                  Arsenal       Tottenham
# 53         1           1 2023-01-22                  Arsenal  Manchester Utd
# 54         0           0 2023-02-04                  Arsenal         Everton
# 55         0           1 2023-02-11                  Arsenal       Brentford
# ...      ...         ...        ...                      ...             ...
# 1700       1           0 2023-10-21  Wolverhampton Wanderers     Bournemouth
# 1701       0           0 2023-10-28  Wolverhampton Wanderers   Newcastle Utd
# 1702       0           0 2023-11-04  Wolverhampton Wanderers   Sheffield Utd
# 1703       1           1 2023-11-11  Wolverhampton Wanderers       Tottenham
# 1704       0           0 2023-11-27  Wolverhampton Wanderers          Fulham
#
#      result
# 51        D
# 52        W
# 53        W
# 54        L
# 55        D
# ...     ...
# 1700      W
# 1701      D
# 1702      L
# 1703      W
# 1704      L
#
# [682 rows x 6 columns]

# %% [markdown]
# ### Combining Home and Away Preds

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key
    
# Dictionary for renaming specific football teams
map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}

# Initializing a MissingDict instance with the team mapping
mapping = MissingDict(**map_values)

# %%
mapping["Brighton and Hove Albion"]
# Out:
# 'Brighton'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  prediction       date                     team        opponent  \
# 51         0           1 2023-01-03                  Arsenal   Newcastle Utd
# 52         1           1 2023-01-15                  Arsenal       Tottenham
# 53         1           1 2023-01-22                  Arsenal  Manchester Utd
# 54         0           0 2023-02-04                  Arsenal         Everton
# 55         0           1 2023-02-11                  Arsenal       Brentford
# ...      ...         ...        ...                      ...             ...
# 1700       1           0 2023-10-21  Wolverhampton Wanderers     Bournemouth
# 1701       0           0 2023-10-28  Wolverhampton Wanderers   Newcastle Utd
# 1702       0           0 2023-11-04  Wolverhampton Wanderers   Sheffield Utd
# 1703       1           1 2023-11-11  Wolverhampton Wanderers       Tottenham
# 1704       0           0 2023-11-27  Wolverhampton Wanderers          Fulham
#
#      result new_team
# 51        D  Arsenal
# 52        W  Arsenal
# 53        W  Arsenal
# 54        L  Arsenal
# 55        D  Arsenal
# ...     ...      ...
# 1700      W   Wolves
# 1701      D   Wolves
# 1702      L   Wolves
# 1703      W   Wolves
# 1704      L   Wolves
#
# [682 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           0             1 2023-01-03                  Arsenal
# 1           1             1 2023-01-15                  Arsenal
# 2           1             1 2023-01-22                  Arsenal
# 3           0             0 2023-02-04                  Arsenal
# 4           0             1 2023-02-11                  Arsenal
# ..        ...           ...        ...                      ...
# 628         1             0 2023-10-21  Wolverhampton Wanderers
# 629         0             0 2023-10-28  Wolverhampton Wanderers
# 630         0             0 2023-11-04  Wolverhampton Wanderers
# 631         1             1 2023-11-11  Wolverhampton Wanderers
# 632         0             0 2023-11-27  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0     Newcastle Utd        D    Arsenal         0             0
# 1         Tottenham        W    Arsenal         0             0
# 2    Manchester Utd        W    Arsenal         0             1
# 3           Everton        L    Arsenal         1             0
# 4         Brentford        D    Arsenal         0             0
# ..              ...      ...        ...       ...           ...
# 628     Bournemouth        W     Wolves         0             0
# 629   Newcastle Utd        D     Wolves         0             1
# 630   Sheffield Utd        L     Wolves         1             0
# 631       Tottenham        W     Wolves         0             0
# 632          Fulham        L     Wolves         1             0
#
#                 team_y opponent_y result_y        new_team_y
# 0     Newcastle United    Arsenal        D     Newcastle Utd
# 1    Tottenham Hotspur    Arsenal        L         Tottenham
# 2    Manchester United    Arsenal        L    Manchester Utd
# 3              Everton    Arsenal        W           Everton
# 4            Brentford    Arsenal        D         Brentford
# ..                 ...        ...      ...               ...
# 628        Bournemouth     Wolves        L       Bournemouth
# 629   Newcastle United     Wolves        D     Newcastle Utd
# 630   Sheffield United     Wolves        W  Sheffield United
# 631  Tottenham Hotspur     Wolves        L         Tottenham
# 632             Fulham     Wolves        W            Fulham
#
# [633 rows x 13 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    82
# 0    46
# Name: count, dtype: int64

# %%
82 / 128
# Out:
# 0.640625
